# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(color_codes=True)
tips = sns.load_dataset("tips")
sns.regplot(x="total_bill", y="tip", data=tips)

# https://seaborn.pydata.org/tutorial/regression.html
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x1c39f931548&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
sns.lmplot(x="total_bill", y="tip", data=tips)
# Out:
# &lt;seaborn.axisgrid.FacetGrid at 0x1c3a2c45e08&gt;
# &lt;Figure size 360x360 with 1 Axes&gt;

# %%
anscombe = sns.load_dataset("anscombe")
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'I'"), ci=None, scatter_kws={"s": 80})
# Out:
# &lt;seaborn.axisgrid.FacetGrid at 0x1c3a2cbc708&gt;
# &lt;Figure size 360x360 with 1 Axes&gt;

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"), ci=None, scatter_kws={"s": 80})
# Out:
# &lt;seaborn.axisgrid.FacetGrid at 0x1c3a2d363c8&gt;
# &lt;Figure size 360x360 with 1 Axes&gt;

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"), order=2, ci=None, scatter_kws={"s": 80})
# Out:
# &lt;seaborn.axisgrid.FacetGrid at 0x1c3a2db4c88&gt;
# &lt;Figure size 360x360 with 1 Axes&gt;

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'III'"), ci=None, scatter_kws={"s": 80})
# Out:
# &lt;seaborn.axisgrid.FacetGrid at 0x1c3a2e2dd48&gt;
# &lt;Figure size 360x360 with 1 Axes&gt;
